# %%
library(qiime2R)
library(tidyr)
library(tibble)
library(ggplot2)
library(microbiome)
library(phyloseq)
library("tidyverse")
library("dplyr")
library(ggpmisc)
# Out:
# Loading required package: phyloseq
#
#
# microbiome R package (microbiome.github.com)
#
#
#
#  Copyright (C) 2011-2020 Leo Lahti,
#     Sudarshan Shetty et al. <microbiome.github.io>
#
#
#
# Attaching package: ‘microbiome’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
#
# The following object is masked from ‘package:base’:
#
#     transform
#
#
# ── Attaching packages ────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ readr   2.1.2     ✔ stringr 1.4.0
# ✔ purrr   0.3.4     ✔ forcats 0.5.1
# ✔ dplyr   1.0.9
#
# ── Conflicts ───────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ microbiome::alpha() masks ggplot2::alpha()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()
#
# Loading required package: ggpp
#
#
# Attaching package: ‘ggpp’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     annotate
#
#
# Warning message in .recacheSubclasses(def@className, def, env):
# “undefined subclass "numericVector" of class "Mnumeric"; definition not updated”

# %%
# Read in the 16S qza files and clean them up for phyloseq
ASVs <- read_qza("/Users/stephanie.rosales/Documents/omics_projects/Resitada/qiime_output/table-BacArc_resistada.qza")
ASVs <- ASVs$data # Extract the count data from list
taxa_16S <- read_qza("/Users/stephanie.rosales/Documents/omics_projects/Resitada/qiime_output/taxonomy_resistada.qza")
taxa_16S <- taxa_16S$data %>% as_tibble() %>% separate(Taxon, sep=";",
c("Kingdom", "Phylum", "Class", "Order", "Family", "Genus", "Species")) %>% 
# Convert taxonomy info to data frame with correct taxonomy labels
#taxa <- taxa_16S[-1,]
select(-Confidence) %>% arrange(Feature.ID) %>% mutate(ASV = 1:n()) %>% 
mutate(newcol = "ASV") %>%
unite("ASVs", newcol:ASV) %>%
mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "o__",
                replacement = "")
#asv_tab$asv_id <- rownames(asv_tab) # add a new column for ids
tree_file <-read_qza("/Users/stephanie.rosales/Documents/omics_projects/Resitada/qiime_output/rooted-BacArc_resistada.qza")$data
# Out:
# Warning message:
# “Expected 7 pieces. Missing pieces filled with `NA` in 5374 rows [3, 6, 9, 11, 12, 14, 15, 16, 17, 18, 22, 23, 27, 31, 36, 38, 42, 45, 49, 51, ...].”

# %%
meta = read.csv("/Users/stephanie.rosales/Documents/omics_projects/Resitada/metadata_RESISTADA.csv", 
                header = T, row.names = 1,
na.strings = c("", "NA"))

# %%
ps= phyloseq(otu_table(ASVs, taxa_are_rows= T),
tax_table(as.data.frame(taxa_16S) %>% column_to_rownames("Feature.ID") %>%
as.matrix()), sample_data(meta), tree_file)
ps

dups = c("N169_256_R2", "N157_265_R2", "N165_296_R2", "N161_A067_R2", "N185_A088_R2",
                                 "N164_A089_R2","N119_A107","N267_A110","N7_A114", "N156_A115","N158_A116",
                                 "N101_A118","N160_A119","N277_A125")

ps = subset_samples(ps, !ID %in% dups & Genotype!=c("U41"))
                                                    #,"U44")) 
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 280 samples ]
# sample_data() Sample Data:       [ 280 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 257 samples ]
# sample_data() Sample Data:       [ 257 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]

# %%
ps_razor =subset_samples(ps, Type=="Razor")
ps_razor

ps_razor_nr =subset_taxa(ps_razor, Genus!="g__MD3-55" )
ps_razor_nr

ps_Clipped =subset_samples(ps, Type=="Clipped")
ps_Clipped

ps_clip_nr =subset_taxa(ps_Clipped, Genus!="g__MD3-55" )
ps_clip_nr

ps_neg =subset_samples(ps, Type=="Neg")
ps_neg

ps_paired = subset_samples(ps_Clipped, Pairs=="paired")
ps_paired
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 60 samples ]
# sample_data() Sample Data:       [ 60 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 7725 taxa and 60 samples ]
# sample_data() Sample Data:       [ 60 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 7725 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 7725 tips and 6818 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 192 samples ]
# sample_data() Sample Data:       [ 192 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 7725 taxa and 192 samples ]
# sample_data() Sample Data:       [ 192 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 7725 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 7725 tips and 6818 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 5 samples ]
# sample_data() Sample Data:       [ 5 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 9710 taxa and 135 samples ]
# sample_data() Sample Data:       [ 135 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 9710 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 9710 tips and 8540 internal nodes ]

# %%
                        

ps_fill_clip = filter_taxa(ps_Clipped, function(x) sum(x > 5) > (0.01*length(x)), TRUE)
ps_fill_clip
                           

                                                      
ps_fill_pair = filter_taxa(ps_paired, function(x) sum(x > 10) > (0.015*length(x)), TRUE)
ps_fill_pair
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1913 taxa and 192 samples ]
# sample_data() Sample Data:       [ 192 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 1913 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 1913 tips and 1604 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 922 taxa and 135 samples ]
# sample_data() Sample Data:       [ 135 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 922 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 922 tips and 758 internal nodes ]

# %%
GoodTaxa = c(
"c4067f49ab443e01537a281084d61ee8",
"41861cce34e32070bc99d36682bf7540",
"8c8c28d133dc228ffc7ba770eee7caba",
"a375bcfe89e6846168661528279a2e38",
"57fe1c8ee9650e492328741c8f86a925",
"615834b295798beef85aedd0dccb7cdf",
"ac6820155a85d9cc15f8f62406e10e42",
"1f388d6a52fb1fe4e6010cd40d4cbda6",
"f242850c598d509ac98aea5999f2779f",
"3790ac5be14bbbdc8719ce6632dcb64b",
"317148b78ed8ecbf25c5448e8b5e0cf5",
"c429cce2851f42f0d5a5f2b50fe18e33",
"57cae3e69e447f81b06a7ab5275a3ea8",
#"2180b5f4284c6a69ed3d7f81ccf42793",
"ff3e7637bd5aac86cff3b72f9ee78f47",
"2694a0d7455819a55a4bb157f5a9fba5",
"58a75ecc587c36de8b4bbbac0c6efff2",
"c26b47e8b0fd4b379a2e0772b3fb75fd",
"3db77d995f6026535328d067e4a9032c",
"1788860a6d5db952c73537bc4f00e6ec")
allTaxa = taxa_names(ps_Clipped)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, ps_paired)
#sig_psr =subset_samples(sig_psr, Days=="Day75")
sig_psr 

melt_ps_treat <- sig_psr %>%
psmelt() #%>% 
#drop_na(Abundance)  %>% 
#filter(Days=="Day_75")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 19 taxa and 135 samples ]
# sample_data() Sample Data:       [ 135 samples by 53 sample variables ]
# tax_table()   Taxonomy Table:    [ 19 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 19 tips and 16 internal nodes ]

# %%
melt_ps_treat  %>%
filter(Abundance >0) %>%
filter(Nutrients=="NH4") %>%
#filter(Genotype!="U44") %>%
mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "g__",
                replacement = "")  %>%

mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "f__",
                replacement = "")  %>%
ggplot(
       aes(x=surv, y= Abundance, color=Genotype)) + 
geom_point(aes(color=Genotype) , alpha=.6) + 
theme_bw() +
#geom_bar(stat = "identity",position="fill") +
#geom_boxplot() +
geom_smooth(method='lm', color="black") +

 stat_poly_eq(formula = y ~ x,
                eq.with.lhs = "italic(hat(y))~`=`~",
                aes(label = paste( ..rr.label.., ..p.value.label.., sep = "~~~")), 
                parse = TRUE, label.y = "bottom", label.x = "right", color="black",
             rr.digits = 3, , size = 2) +

 stat_poly_eq(aes(label = paste(..eq.label.., sep = "~~~")), 
               label.y = 0.15,
               eq.with.lhs = "italic(hat(y))~`=`~",
               eq.x.rhs = "~italic(x)",
               formula = y ~ x, parse = TRUE, size = 2,
               label.x = "right", color="black") +

ylab("Relative Abundance") +
xlab("Survivorship Day") +

facet_wrap(.~Order*Family*Genus, scales="free_x") +
scale_color_manual(values=c("#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588",
                           "#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588"
                          )) +
#geom_point(aes(size= Abundance), alpha=0.4) +
theme_bw() +
theme(legend.title = element_text(size=5)) +
scale_y_continuous(trans = "log10") +
labs(fill='Taxon')  +
#ylab("Relative Abundance") +
#xlab("Genotype") +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=10)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=4)) +
theme(axis.title.x = element_text(size = 4)) +
theme(axis.title.y = element_text(size = 4)) +
#theme(axis.text.y = element_blank()) +
theme(axis.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
#theme(axis.text.y=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
guides(color = guide_legend(keywidth = 0.2, , keyheight =.40, ncol=1)) +
#theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=4)) +
theme(strip.text.x = element_text(size = 5)) 

ggsave("/Users/stephanie.rosales/Documents/omics_projects/Resitada/figures/lm_NUT.jpg", 
      width = 4, height = 4, units = "in", dpi=300)
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
GoodTaxa = c(
"059c3e69b66695d46404b7aaeace731b",
"f7848134c8fef10bf91baeea87aa9b49",
"2180b5f4284c6a69ed3d7f81ccf42793",
"2256abda648749b2efbbc5ef6cf625d8",
"a24e19ec3a1891f7fee6cfa389fc09bd",
"2549b8aa248e7607235d17caa2578426",
"2858b9fde3b089e24129923e26bfb2e7",
"cd1c36a7f04147fce84ecdb93d5ef05c",
"fea4638d48e009fdfdec27a381a41b41",
"380e94062cd8f44ea50814193ad56225",
"0dce0a792e9123fa5535d2876b7f1fff",
"729a9b129d2e56636b4173e4d2d3cba1",
"57cae3e69e447f81b06a7ab5275a3ea8",
"c429cce2851f42f0d5a5f2b50fe18e33",
"1788860a6d5db952c73537bc4f00e6ec",
"dd854d3a4e751969b6b758713701ba6d",
"af9929b8c403fc72989769d9876fc007",
"ff3e7637bd5aac86cff3b72f9ee78f47",
"615834b295798beef85aedd0dccb7cdf",
"c4ba45067e12fe7ff43a334c839aded4",
"1f388d6a52fb1fe4e6010cd40d4cbda6",
"f4e89e31c7b0b00c0a5ad41a4ffa09da",
"2de04f6ef9c9089393685ee308a4ec93",
"9c37ff0de653f2dba99bce320e9ffe32",
"7b93a18f6d259a40bc1913d192c5ea71",
"d3671ae472095940ceb14d0af99cd4f5",
"57802246ce60e66d684511377ef5e2cc",
"6814d83c921ece2808ef7e0bd8c284a7",
"c2e0cafeeb1e69533d2bebd4f3ff5a87",
"41861cce34e32070bc99d36682bf7540",
"efd45dbce0ff782596ca0cde99a572a8",
"50434cdbb2bf05ad54615c83059a4367")

allTaxa = taxa_names(ps_paired)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, ps_paired)
#sig_psr =subset_samples(sig_psr, Days=="Day75")
sig_psr 

melt_ps_treat <- sig_psr %>%
psmelt() #%>% 
#drop_na(Abundance)  %>% 
#filter(Days=="Day_75")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 32 taxa and 135 samples ]
rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 13    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 14    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 15    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 16    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 17    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 18    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 19    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 20    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 21    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 22    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 23    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 24    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 25    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 26    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 27    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 28    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 29    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# 30    Rickettsiales  f__Fokiniaceae    g__MD3-55  NA
# ⋮    ⋮              ⋮                 ⋮           ⋮
# 1531  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1532  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1533  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1534  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1535  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1536  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1537  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1538  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1539  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1540  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1541  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1542  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1543  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1544  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1545  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1546  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1547  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1548  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1549  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1550  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1551  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1552  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1553  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1554  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1555  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1556  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1557  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1558  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1559  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
# 1560  Myxococcales   f__Myxococcaceae  g__P3OB-42  s__uncultured_bacterium
#      ASVs
# 1    ASV_10105
# 2    ASV_7769
# 3    ASV_1233
# 4    ASV_10105
# 5    ASV_6931
# 6    ASV_951
# 7    ASV_10105
# 8    ASV_10105
# 9    ASV_7769
# 10   ASV_7769
# 11   ASV_10105
# 12   ASV_3537
# 13   ASV_7769
# 14   ASV_10105
# 15   ASV_10105
# 16   ASV_10105
# 17   ASV_1233
# 18   ASV_1233
# 19   ASV_3874
# 20   ASV_10105
# 21   ASV_10105
# 22   ASV_1233
# 23   ASV_7769
# 24   ASV_7769
# 25   ASV_10105
# 26   ASV_6931
# 27   ASV_7769
# 28   ASV_7769
# 29   ASV_10105
# 30   ASV_10105
# ⋮    ⋮
# 1531 ASV_9695
# 1532 ASV_9695
# 1533 ASV_9695
# 1534 ASV_9695
# 1535 ASV_9695
# 1536 ASV_9695
# 1537 ASV_9695
# 1538 ASV_9695
# 1539 ASV_9695
# 1540 ASV_9695
# 1541 ASV_9695
# 1542 ASV_9695
# 1543 ASV_9695
# 1544 ASV_9695
# 1545 ASV_9695
# 1546 ASV_9695
# 1547 ASV_9695
# 1548 ASV_9695
# 1549 ASV_9695
# 1550 ASV_9695
# 1551 ASV_9695
# 1552 ASV_9695
# 1553 ASV_9695
# 1554 ASV_9695
# 1555 ASV_9695
# 1556 ASV_9695
# 1557 ASV_9695
# 1558 ASV_9695
# 1559 ASV_9695
# 1560 ASV_9695

# %%
melt_ps_treat  %>%
filter(Phylum!=" NA") %>%
#filter(Genotype!="U44") %>%
filter(Diseased=="Placebo") %>%
mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "g__",
                replacement = "")  %>%

mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "f__",
                replacement = "")  %>%

ggplot(
       aes(x=surv, y= Abundance, color=Genotype)) + 
theme_bw() +
geom_smooth(method='lm', color="black") +

 stat_poly_eq(formula = y ~ x,
                eq.with.lhs = "italic(hat(y))~`=`~",
                aes(label = paste( ..rr.label.., ..p.value.label.., sep = "~~~")), 
                parse = TRUE, label.y = "bottom", label.x = "right", color="black",
             rr.digits = 3, , size = 2) +

 stat_poly_eq(aes(label = paste(..eq.label.., sep = "~~~")), 
               label.y = 0.15,
               eq.with.lhs = "italic(hat(y))~`=`~",
               eq.x.rhs = "~italic(x)",
               formula = y ~ x, parse = TRUE, size = 2,
               label.x = "right", color="black") +

geom_point(aes(color=Genotype) , alpha=.6) + 
ylab("Relative Abundance") +
xlab("Survivorship") +


facet_wrap(.~Order*Family*Genus, scales="free_x") +
scale_color_manual(values=c("#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588",
                           "#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588"
                          )) +
#geom_point(aes(size= Abundance), alpha=0.4) +
theme_bw() +
theme(legend.title = element_text(size=4)) +
scale_y_continuous(trans = "log10") +
labs(fill='Taxon')  +
#ylab("Relative Abundance") +
#xlab("Genotype") +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
theme(axis.title.x = element_text(size = 4)) +
theme(axis.title.y = element_text(size = 4)) +
#theme(axis.text.y = element_blank()) +
theme(axis.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
#theme(axis.text.y=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
guides(color = guide_legend(keywidth = 0.2, , keyheight =.40, ncol=1)) +
#theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=4)) +
theme(strip.text.x = element_text(size = 4)) 


ggsave("/Users/stephanie.rosales/Documents/omics_projects/Resitada/figures/lm_DLW.u44.jpg", 
      width = 5, height = 5, units = "in", dpi=300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Removed 1203 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# plot without title

# %%
melt_ps_treat  %>%
filter(Phylum!=" NA") %>%
filter(Genotype!="U44") %>%
filter(Diseased=="Placebo") %>%
mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "g__",
                replacement = "")  %>%

mutate_if(
                is.character, 
                stringr::str_replace_all, 
                pattern = "f__",
                replacement = "")  %>%

ggplot(
       aes(x=surv, y= Abundance, color=Genotype)) + 
theme_bw() +
geom_smooth(method='lm', color="black") +

 stat_poly_eq(formula = y ~ x,
                eq.with.lhs = "italic(hat(y))~`=`~",
                aes(label = paste( ..rr.label.., ..p.value.label.., sep = "~~~")), 
                parse = TRUE, label.y = "bottom", label.x = "right", color="black",
             rr.digits = 3, , size = 2) +

 stat_poly_eq(aes(label = paste(..eq.label.., sep = "~~~")), 
               label.y = 0.15,
               eq.with.lhs = "italic(hat(y))~`=`~",
               eq.x.rhs = "~italic(x)",
               formula = y ~ x, parse = TRUE, size = 2,
               label.x = "right", color="black") +

geom_point(aes(color=Genotype) , alpha=.6) + 
ylab("Relative Abundance") +
xlab("Survivorship") +


facet_wrap(.~Order*Family*Genus, scales="free_x") +
scale_color_manual(values=c("#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588",
                           "#3CB371","tan","#5F7FC7", "orange","#ADFF2F", 
                           "#CD9BCD", "gray80", "darkolivegreen4", "#673770","#D14285", 
                           "#8569D5", "#5E738F","#AD6F3B",
                          "lightblue", "salmon","Navy", "#CBD588"
                          )) +
#geom_point(aes(size= Abundance), alpha=0.4) +
theme_bw() +
theme(legend.title = element_text(size=4)) +
scale_y_continuous(trans = "log10") +
labs(fill='Taxon')  +
#ylab("Relative Abundance") +
#xlab("Genotype") +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
theme(axis.title.x = element_text(size = 4)) +
theme(axis.title.y = element_text(size = 4)) +
#theme(axis.text.y = element_blank()) +
theme(axis.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
#theme(axis.text.y=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
guides(color = guide_legend(keywidth = 0.2, , keyheight =.40, ncol=1)) +
#theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=4)) +
theme(strip.text.x = element_text(size = 4)) 


ggsave("/Users/stephanie.rosales/Documents/omics_projects/Resitada/figures/lm_DLNou44.jpg", 
      width = 5, height = 5, units = "in", dpi=300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “Removed 974 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 974 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Removed 974 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# `geom_smooth()` using formula 'y ~ x'
#
# Warning message:
# “Removed 974 rows containing non-finite values (stat_smooth).”
# Warning message:
# “Removed 974 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Removed 974 rows containing non-finite values (stat_poly_eq).”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# Warning message:
# “Not enough data to perform fit for group 1; computing mean instead.”
# plot without title

# %%
tax_table(sig_psr)
# Out:
#                                  Kingdom     Phylum
# a24e19ec3a1891f7fee6cfa389fc09bd d__Bacteria NA
# fea4638d48e009fdfdec27a381a41b41 d__Bacteria NA
# 6814d83c921ece2808ef7e0bd8c284a7 d__Bacteria NA
# c4ba45067e12fe7ff43a334c839aded4 d__Bacteria NA
# 2180b5f4284c6a69ed3d7f81ccf42793 d__Bacteria NA
# 0dce0a792e9123fa5535d2876b7f1fff d__Bacteria NA
# f7848134c8fef10bf91baeea87aa9b49 d__Bacteria NA
# 059c3e69b66695d46404b7aaeace731b d__Bacteria NA
# 2549b8aa248e7607235d17caa2578426 d__Bacteria  p__Proteobacteria
# c2e0cafeeb1e69533d2bebd4f3ff5a87 d__Bacteria  p__Proteobacteria
# 2256abda648749b2efbbc5ef6cf625d8 d__Bacteria  p__Proteobacteria
# 380e94062cd8f44ea50814193ad56225 d__Bacteria  p__Actinobacteriota
# f4e89e31c7b0b00c0a5ad41a4ffa09da d__Bacteria  p__Myxococcota
# 9c37ff0de653f2dba99bce320e9ffe32 d__Bacteria  p__Proteobacteria
# 41861cce34e32070bc99d36682bf7540 d__Bacteria  p__Proteobacteria
# af9929b8c403fc72989769d9876fc007 d__Bacteria  p__Proteobacteria
# ff3e7637bd5aac86cff3b72f9ee78f47 d__Bacteria  p__Proteobacteria
# 1788860a6d5db952c73537bc4f00e6ec d__Bacteria  p__Proteobacteria
# 57cae3e69e447f81b06a7ab5275a3ea8 d__Bacteria  p__Proteobacteria
# c429cce2851f42f0d5a5f2b50fe18e33 d__Bacteria  p__Proteobacteria
# 615834b295798beef85aedd0dccb7cdf d__Bacteria  p__Proteobacteria
# 50434cdbb2bf05ad54615c83059a4367 d__Bacteria  p__Proteobacteria
# 7b93a18f6d259a40bc1913d192c5ea71 d__Bacteria  p__Proteobacteria
# efd45dbce0ff782596ca0cde99a572a8 d__Bacteria  p__Proteobacteria
# 1f388d6a52fb1fe4e6010cd40d4cbda6 d__Bacteria  p__Proteobacteria
# dd854d3a4e751969b6b758713701ba6d d__Bacteria  p__Proteobacteria
# 2858b9fde3b089e24129923e26bfb2e7 d__Bacteria  p__Proteobacteria
# 729a9b129d2e56636b4173e4d2d3cba1 d__Bacteria  p__Proteobacteria
# 57802246ce60e66d684511377ef5e2cc d__Bacteria  p__Proteobacteria
# d3671ae472095940ceb14d0af99cd4f5 d__Bacteria  p__Proteobacteria
# cd1c36a7f04147fce84ecdb93d5ef05c d__Bacteria  p__Proteobacteria
# 2de04f6ef9c9089393685ee308a4ec93 d__Bacteria  p__Proteobacteria
#                                  Class                   Order
# a24e19ec3a1891f7fee6cfa389fc09bd NA                      NA
# 7b93a18f6d259a40bc1913d192c5ea71  g__MD3-55
# efd45dbce0ff782596ca0cde99a572a8  g__MD3-55
# 1f388d6a52fb1fe4e6010cd40d4cbda6  g__MD3-55
# dd854d3a4e751969b6b758713701ba6d  g__Burkholderia-Caballeronia-Paraburkholderia
# 2858b9fde3b089e24129923e26bfb2e7  g__Thalassotalea
# 729a9b129d2e56636b4173e4d2d3cba1  g__Pseudoalteromonas
# 57802246ce60e66d684511377ef5e2cc  g__Pseudoalteromonas
# d3671ae472095940ceb14d0af99cd4f5  g__Pseudoalteromonas
# cd1c36a7f04147fce84ecdb93d5ef05c  g__Vibrio
# 2de04f6ef9c9089393685ee308a4ec93  g__Vibrio
#                                  Species                       ASVs
# a24e19ec3a1891f7fee6cfa389fc09bd NA                            ASV_6465
# fea4638d48e009fdfdec27a381a41b41 NA                            ASV_10076
# 6814d83c921ece2808ef7e0bd8c284a7 NA                            ASV_4184
# c4ba45067e12fe7ff43a334c839aded4 NA                            ASV_7799
# 2180b5f4284c6a69ed3d7f81ccf42793 NA                            ASV_1332
# 0dce0a792e9123fa5535d2876b7f1fff NA                            ASV_559
# f7848134c8fef10bf91baeea87aa9b49 NA                            ASV_9807
# 059c3e69b66695d46404b7aaeace731b NA                            ASV_209
# 2549b8aa248e7607235d17caa2578426 NA                            ASV_1483
# c2e0cafeeb1e69533d2bebd4f3ff5a87 NA                            ASV_7717
# 2256abda648749b2efbbc5ef6cf625d8 NA                            ASV_1372
# 380e94062cd8f44ea50814193ad56225 NA                            ASV_2240
# f4e89e31c7b0b00c0a5ad41a4ffa09da  s__uncultured_bacterium      ASV_9695
# 9c37ff0de653f2dba99bce320e9ffe32  s__Acropora_cervicornis      ASV_6224
# 41861cce34e32070bc99d36682bf7540 NA                            ASV_2645
# af9929b8c403fc72989769d9876fc007 NA                            ASV_6931
# ff3e7637bd5aac86cff3b72f9ee78f47 NA                            ASV_10105
# 1788860a6d5db952c73537bc4f00e6ec NA                            ASV_951
# 57cae3e69e447f81b06a7ab5275a3ea8 NA                            ASV_3537
# c429cce2851f42f0d5a5f2b50fe18e33 NA                            ASV_7769
# 615834b295798beef85aedd0dccb7cdf NA                            ASV_3874
# 50434cdbb2bf05ad54615c83059a4367 NA                            ASV_3242
# 7b93a18f6d259a40bc1913d192c5ea71 NA                            ASV_4954
# efd45dbce0ff782596ca0cde99a572a8 NA                            ASV_9520
# 1f388d6a52fb1fe4e6010cd40d4cbda6 NA                            ASV_1233
# dd854d3a4e751969b6b758713701ba6d NA                            ASV_8770
# 2858b9fde3b089e24129923e26bfb2e7  s__Thalassotalea_ganghwensis ASV_1612
# 729a9b129d2e56636b4173e4d2d3cba1 NA                            ASV_4591
# 57802246ce60e66d684511377ef5e2cc NA                            ASV_3522
# d3671ae472095940ceb14d0af99cd4f5 NA                            ASV_8384
# cd1c36a7f04147fce84ecdb93d5ef05c NA                            ASV_8137
# 2de04f6ef9c9089393685ee308a4ec93 NA                            ASV_1840
